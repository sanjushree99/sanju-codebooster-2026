# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjushree99/sanju-codebooster-2026/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.2)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import year, month, to_date, col, round as spark_round
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import year, month, to_date, col, round as spark_round
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#Create SparkSession

spark = SparkSession.builder \
    .appName('Day4_Bigdata_Sales') \
    .config('spark.sql.adaptive.enabled', 'true') \
    .getOrCreate()


print(f'Spark Version : {spark.version}')
print(f'SparkSession : ACTIVE')
print(f'Application : {spark.sparkContext.appName}')
# Out:
# Spark Version : 4.0.2
# SparkSession : ACTIVE
# Application : Day4_Bigdata_Sales

# %%
df_bronze = spark.read \
     .option('header', 'true') \
     .option('inferSchema', 'true') \
     .csv('large_sales_data.csv')

print('=== BRONZE LAYER - Raw Data ===')
print(f'Rows     : {df_bronze.count()}')
print(f'Names    : {df_bronze.columns}')
print()
df_bronze.printSchema()
# Out:
# === BRONZE LAYER - Raw Data ===
# Rows     : 5000
# Names    : ['order_id', 'customer_name', 'product', 'category', 'quantity', 'unit_price', 'revenue', 'order_date', 'city', 'region', 'sales_rep', 'payment_method', 'order_status']
#
# root
#  |-- order_id: integer (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: integer (nullable = true)
#  |-- revenue: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- city: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- sales_rep: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
df_bronze = spark.read \
     .option('header', 'true') \
     .option('inferSchema', 'true') \
     .csv('large_sales_data.csv')

print('=== BRONZE LAYER - Raw Data ===')
print(f'Rows     : {df_bronze.count()}')
print(f'Names    : {df_bronze.columns}')
print()
df_bronze.printSchema()
# Out:
# === BRONZE LAYER - Raw Data ===
# Rows     : 5000
# Names    : ['order_id', 'customer_name', 'product', 'category', 'quantity', 'unit_price', 'revenue', 'order_date', 'city', 'region', 'sales_rep', 'payment_method', 'order_status']
#
# root
#  |-- order_id: integer (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: integer (nullable = true)
#  |-- revenue: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- city: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- sales_rep: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
print('First 5 rows:')
df_bronze.show(5, truncate=False)

print('\Basic statistics for numeric columns')
df_bronze.select('quantity', 'unit_price', 'revenue').describe().show()
# Out:
# First 5 rows:
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# |order_id|customer_name|product   |category   |quantity|unit_price|revenue|order_date|city     |region|sales_rep  |payment_method  |order_status|
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# |1001    |Sneha Reddy  |Monitor   |Electronics|12      |22000     |264000 |2023-05-21|Mumbai   |West  |Meera Patel|UPI             |Delivered   |
# |1002    |Ramesh Kumar |Printer   |Electronics|10      |12000     |120000 |2023-08-05|Delhi    |North |Anil Sharma|Credit Card     |Shipped     |
# |1003    |Rahul Mishra |Mouse     |Accessories|10      |800       |8000   |2023-01-14|Ahmedabad|West  |Meera Patel|Cash on Delivery|Shipped     |
# |1004    |Suresh Rao   |Tablet    |Electronics|5       |32000     |160000 |2023-01-04|Surat    |West  |Ravi Kumar |Cash on Delivery|Processing  |
# |1005    |Priya Patel  |Headphones|Electronics|4       |3500      |14000  |2023-06-22|Bangalore|South |Sunita Rao |Cash on Delivery|Delivered   |
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# only showing top 5 rows
# \Basic statistics for numeric columns
# +-------+-----------------+------------------+------------------+
# |summary|         quantity|        unit_price|           revenue|
# +-------+-----------------+------------------+------------------+
# |  count|             5000|              5000|              5000|
# |   mean|           7.9536|          12496.86|          99169.52|
# | stddev|4.275313169878912|14857.384309295603|145972.97195261103|
# |    min|                1|               600|               600|
# |    max|               15|             45000|            675000|
# +-------+-----------------+------------------+------------------+

# %%
print('First 5 rows:')
df_bronze.show(5, truncate=False)

print('\Basic statistics for numeric columns')
df_bronze.select('quantity', 'unit_price', 'revenue').describe().show()
# Out:
# First 5 rows:
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# |order_id|customer_name|product   |category   |quantity|unit_price|revenue|order_date|city     |region|sales_rep  |payment_method  |order_status|
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# |1001    |Sneha Reddy  |Monitor   |Electronics|12      |22000     |264000 |2023-05-21|Mumbai   |West  |Meera Patel|UPI             |Delivered   |
# |1002    |Ramesh Kumar |Printer   |Electronics|10      |12000     |120000 |2023-08-05|Delhi    |North |Anil Sharma|Credit Card     |Shipped     |
# |1003    |Rahul Mishra |Mouse     |Accessories|10      |800       |8000   |2023-01-14|Ahmedabad|West  |Meera Patel|Cash on Delivery|Shipped     |
# |1004    |Suresh Rao   |Tablet    |Electronics|5       |32000     |160000 |2023-01-04|Surat    |West  |Ravi Kumar |Cash on Delivery|Processing  |
# |1005    |Priya Patel  |Headphones|Electronics|4       |3500      |14000  |2023-06-22|Bangalore|South |Sunita Rao |Cash on Delivery|Delivered   |
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# only showing top 5 rows
# \Basic statistics for numeric columns
# +-------+-----------------+------------------+------------------+
# |summary|         quantity|        unit_price|           revenue|
# +-------+-----------------+------------------+------------------+
# |  count|             5000|              5000|              5000|
# |   mean|           7.9536|          12496.86|          99169.52|
# | stddev|4.275313169878912|14857.384309295603|145972.97195261103|
# |    min|                1|               600|               600|
# |    max|               15|             45000|            675000|
# +-------+-----------------+------------------+------------------+

# %%
print('First 5 rows:')
df_bronze.show(5, truncate=False)
print(df_bronze.tail(5))

print('\Basic statistics for numeric columns')
df_bronze.select('quantity', 'unit_price', 'revenue').describe().show()
# Out:
# First 5 rows:
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# |order_id|customer_name|product   |category   |quantity|unit_price|revenue|order_date|city     |region|sales_rep  |payment_method  |order_status|
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# |1001    |Sneha Reddy  |Monitor   |Electronics|12      |22000     |264000 |2023-05-21|Mumbai   |West  |Meera Patel|UPI             |Delivered   |
# |1002    |Ramesh Kumar |Printer   |Electronics|10      |12000     |120000 |2023-08-05|Delhi    |North |Anil Sharma|Credit Card     |Shipped     |
# |1003    |Rahul Mishra |Mouse     |Accessories|10      |800       |8000   |2023-01-14|Ahmedabad|West  |Meera Patel|Cash on Delivery|Shipped     |
# |1004    |Suresh Rao   |Tablet    |Electronics|5       |32000     |160000 |2023-01-04|Surat    |West  |Ravi Kumar |Cash on Delivery|Processing  |
# |1005    |Priya Patel  |Headphones|Electronics|4       |3500      |14000  |2023-06-22|Bangalore|South |Sunita Rao |Cash on Delivery|Delivered   |
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+
# only showing top 5 rows
# [Row(order_id=5996, customer_name='Ananya Das', product='Mouse', category='Accessories', quantity=13, unit_price=800, revenue=10400, order_date=datetime.date(2023, 11, 18), city='Bangalore', region='South', sales_rep='Meera Patel', payment_method='Net Banking', order_status='Cancelled'), Row(order_id=5997, customer_name='Suresh Rao', product='Webcam', category='Accessories', quantity=9, unit_price=2500, revenue=22500, order_date=datetime.date(2023, 6, 7), city='Chennai', region='South', sales_rep='Sunita Rao', payment_method='Credit Card', order_status='Delivered'), Row(order_id=5998, customer_name='Arjun Nair', product='Webcam', category='Accessories', quantity=1, unit_price=2500, revenue=2500, order_date=datetime.date(2023, 4, 7), city='Jaipur', region='North', sales_rep='Kavya Reddy', payment_method='Net Banking', order_status='Cancelled'), Row(order_id=5999, customer_name='Arjun Nair', product='Laptop', category='Electronics', quantity=14, unit_price=45000, revenue=630000, order_date=datetime.date(2023, 7, 30), city='Delhi', region='North', sales_rep='Ravi Kumar', payment_method='Cash on Delivery', order_status='Shipped'), Row(order_id=6000, customer_name='Arjun Nair', product='Headphones', category='Electronics', quantity=15, unit_price=3500, revenue=52500, order_date=datetime.date(2023, 6, 15), city='Kolkata', region='East', sales_rep='Suresh Iyer', payment_method='UPI', order_status='Delivered')]
# \Basic statistics for numeric columns
# +-------+-----------------+------------------+------------------+
# |summary|         quantity|        unit_price|           revenue|
# +-------+-----------------+------------------+------------------+
# |  count|             5000|              5000|              5000|
# |   mean|           7.9536|          12496.86|          99169.52|
# | stddev|4.275313169878912|14857.384309295603|145972.97195261103|
# |    min|                1|               600|               600|
# |    max|               15|             45000|            675000|
# +-------+-----------------+------------------+------------------+

# %%
df_bronze.write \
    .mode('overwrite') \
    .parquet('sales_bronze.parquet')
print('Bronze Parquet saved: sales_bronze.parquet')
# Out:
# Bronze Parquet saved: sales_bronze.parquet

# %%
import os
def get_dir_size(path):
    """Get total size of a file or directory in KB."""
    if os.path.isfile(path):
        return os.path.getsize(path) / 1024
    total = 0
    for dirpath, dirnames, filenames in os.walk(path):
      for f in filenames:
        total += os.path.getsize(os.path.join(dirpath, f))
    return total / 1024

csv_size = get_dir_size('large_sales_data.csv')
parquet_size = get_dir_size('sales_bronze.parquet')
reduciton = (1 - (parquet_size / csv_size)) * 100

print(f"\nCSV size : {csv_size:.1f} KB")
print(f"Parquet size : {parquet_size:.1f} KB")
print(f'Reduction : {reduciton:.1f} % smaller')
print(f'\nAt 1 TB scale: CSV=1000 GB -> Parquet={1000*(1-(reduciton/100)):.1f} GB')
# Out:
# CSV size : 529.3 KB
# Parquet size : 55.1 KB
# Reduction : 89.6 % smaller
#
# At 1 TB scale: CSV=1000 GB -> Parquet=104.1 GB

# %%
df_bronze = df_bronze.withColumn('total_price_and_revenue', col('unit_price') + col('revenue'))
df_bronze.show(5, truncate=False)

df_bronze.printSchema()
# Out:
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+-----------------------+
# |order_id|customer_name|product   |category   |quantity|unit_price|revenue|order_date|city     |region|sales_rep  |payment_method  |order_status|total_price_and_revenue|
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+-----------------------+
# |1001    |Sneha Reddy  |Monitor   |Electronics|12      |22000     |264000 |2023-05-21|Mumbai   |West  |Meera Patel|UPI             |Delivered   |286000                 |
# |1002    |Ramesh Kumar |Printer   |Electronics|10      |12000     |120000 |2023-08-05|Delhi    |North |Anil Sharma|Credit Card     |Shipped     |132000                 |
# |1003    |Rahul Mishra |Mouse     |Accessories|10      |800       |8000   |2023-01-14|Ahmedabad|West  |Meera Patel|Cash on Delivery|Shipped     |8800                   |
# |1004    |Suresh Rao   |Tablet    |Electronics|5       |32000     |160000 |2023-01-04|Surat    |West  |Ravi Kumar |Cash on Delivery|Processing  |192000                 |
# |1005    |Priya Patel  |Headphones|Electronics|4       |3500      |14000  |2023-06-22|Bangalore|South |Sunita Rao |Cash on Delivery|Delivered   |17500                  |
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+-----------+----------------+------------+-----------------------+
# only showing top 5 rows
# root
#  |-- order_id: integer (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: integer (nullable = true)
#  |-- revenue: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- city: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- sales_rep: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- total_price_and_revenue: integer (nullable = true)

# %%
df_bronze.select("product","revenue","city").show()
# Out:
# +----------+-------+---------+
# |   product|revenue|     city|
# +----------+-------+---------+
# |   Monitor| 264000|   Mumbai|
# |   Printer| 120000|    Delhi|
# |     Mouse|   8000|Ahmedabad|
# |    Tablet| 160000|    Surat|
# |Headphones|  14000|Bangalore|
# |    Webcam|  25000|  Kolkata|
# |   USB Hub|   5400|    Delhi|
# |    Laptop| 585000|  Chennai|
# |Headphones|  38500|   Jaipur|
# |Headphones|  35000|    Delhi|
# |   USB Hub|   9000|Hyderabad|
# |     Mouse|  10400|   Mumbai|
# |   Speaker|  18000|  Kolkata|
# |Headphones|  14000|Bangalore|
# |    Webcam|   7500|  Chennai|
# |  Keyboard|  15600|Bangalore|
# |   Speaker|  40500|   Jaipur|
# |    Webcam|  12500|    Delhi|
# |   Printer| 108000|Bangalore|
# |    Webcam|  22500|Bangalore|
# +----------+-------+---------+
# only showing top 20 rows

# %%
df_bronze.filter(F.col("revenue")>5000).show()
# Out:
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+------------+----------------+------------+-----------------------+
# |order_id|customer_name|   product|   category|quantity|unit_price|revenue|order_date|     city|region|   sales_rep|  payment_method|order_status|total_price_and_revenue|
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+------------+----------------+------------+-----------------------+
# |    1001|  Sneha Reddy|   Monitor|Electronics|      12|     22000| 264000|2023-05-21|   Mumbai|  West| Meera Patel|             UPI|   Delivered|                 286000|
# |    1002| Ramesh Kumar|   Printer|Electronics|      10|     12000| 120000|2023-08-05|    Delhi| North| Anil Sharma|     Credit Card|     Shipped|                 132000|
# |    1003| Rahul Mishra|     Mouse|Accessories|      10|       800|   8000|2023-01-14|Ahmedabad|  West| Meera Patel|Cash on Delivery|     Shipped|                   8800|
# |    1004|   Suresh Rao|    Tablet|Electronics|       5|     32000| 160000|2023-01-04|    Surat|  West|  Ravi Kumar|Cash on Delivery|  Processing|                 192000|
# |    1005|  Priya Patel|Headphones|Electronics|       4|      3500|  14000|2023-06-22|Bangalore| South|  Sunita Rao|Cash on Delivery|   Delivered|                  17500|
# |    1006|   Suresh Rao|    Webcam|Accessories|      10|      2500|  25000|2023-05-16|  Kolkata|  East| Anil Sharma|Cash on Delivery|   Delivered|                  27500|
# |    1007|Kavya Nambiar|   USB Hub|Accessories|       9|       600|   5400|2023-05-31|    Delhi| North|  Priya Nair|             UPI|   Delivered|                   6000|
# |    1008|  Priya Patel|    Laptop|Electronics|      13|     45000| 585000|2023-05-29|  Chennai| South| Meera Patel|     Credit Card|   Cancelled|                 630000|
# |    1009|   Amit Verma|Headphones|Electronics|      11|      3500|  38500|2023-07-06|   Jaipur| North|  Priya Nair|     Net Banking|     Shipped|                  42000|
# |    1010|   Amit Verma|Headphones|Electronics|      10|      3500|  35000|2023-11-22|    Delhi| North| Meera Patel|             UPI|   Cancelled|                  38500|
# |    1011|  Pooja Gupta|   USB Hub|Accessories|      15|       600|   9000|2023-11-24|Hyderabad| South| Meera Patel|     Net Banking|   Delivered|                   9600|
# |    1012|  Kiran Kumar|     Mouse|Accessories|      13|       800|  10400|2023-06-11|   Mumbai|  West|Deepak Joshi|     Credit Card|     Shipped|                  11200|
# |    1013|  Divya Singh|   Speaker|Electronics|       4|      4500|  18000|2023-12-02|  Kolkata|  East| Suresh Iyer|Cash on Delivery|     Shipped|                  22500|
# |    1014| Rahul Mishra|Headphones|Electronics|       4|      3500|  14000|2023-10-15|Bangalore| South|Deepak Joshi|Cash on Delivery|   Cancelled|                  17500|
# |    1015|  Divya Singh|    Webcam|Accessories|       3|      2500|   7500|2023-09-18|  Chennai| South|  Sunita Rao|     Credit Card|   Delivered|                  10000|
# |    1016|  Kiran Kumar|  Keyboard|Accessories|      13|      1200|  15600|2023-12-15|Bangalore| South|  Sunita Rao|Cash on Delivery|   Cancelled|                  16800|
# |    1017| Rahul Mishra|   Speaker|Electronics|       9|      4500|  40500|2023-05-09|   Jaipur| North| Anil Sharma|     Credit Card|  Processing|                  45000|
# |    1018|   Amit Verma|    Webcam|Accessories|       5|      2500|  12500|2023-08-11|    Delhi| North| Kavya Reddy|     Credit Card|  Processing|                  15000|
# |    1019|Kavya Nambiar|   Printer|Electronics|       9|     12000| 108000|2023-02-24|Bangalore| South|Deepak Joshi|             UPI|     Shipped|                 120000|
# |    1020|  Tanvi Mehta|    Webcam|Accessories|       9|      2500|  22500|2023-09-29|Bangalore| South| Anil Sharma|     Net Banking|   Cancelled|                  25000|
# +--------+-------------+----------+-----------+--------+----------+-------+----------+---------+------+------------+----------------+------------+-----------------------+
# only showing top 20 rows

# %%
df_bronze.groupBy("category") \
         .agg(F.sum("revenue").alias("total_revenue"),
              F.count("*").alias("orders"),
              F.avg("revenue").alias("avg_revenue")) \
         .orderBy("total_revenue", ascending=False)
# Out:
# DataFrame[category: string, total_revenue: bigint, orders: bigint, avg_revenue: double]

# %%
top_products = df_bronze \
    .groupBy("product") \
    .agg(
        F.sum('revenue').alias('total_revenue'),
        F.count('order_id').alias('num_orders'),
        F.avg('revenue').alias('avg_order_revenue')
    ) \
    .orderBy('total_revenue', ascending=False) \
    .limit(5)

print('=== Top 5 Products by Revenue ===')
top_products.show(truncate=False)
# Out:
# === Top 5 Products by Revenue ===
# +-------+-------------+----------+------------------+
# |product|total_revenue|num_orders|avg_order_revenue |
# +-------+-------------+----------+------------------+
# |Laptop |182700000    |502       |363944.22310756973|
# |Tablet |135104000    |532       |253954.8872180451 |
# |Monitor|82126000     |481       |170740.12474012474|
# |Printer|44544000     |488       |91278.68852459016 |
# |Speaker|16317000     |470       |34717.02127659575 |
# +-------+-------------+----------+------------------+

# %%
# Aggregate data by region
revenue_by_region = df_bronze \
    .groupBy('region') \
    .agg(
        F.sum('revenue').alias('total_revenue'),
        F.count('order_id').alias('total_orders'),
        F.countDistinct('customer_name').alias('unique_customers')
    ) \
    .orderBy('total_revenue', ascending=False)

print('=== Revenue by Region ===')
revenue_by_region.show(truncate=False)
# Out:
# === Revenue by Region ===
# +------+-------------+------------+----------------+
# |region|total_revenue|total_orders|unique_customers|
# +------+-------------+------------+----------------+
# |West  |198275600    |2021        |15              |
# |South |147145900    |1483        |15              |
# |North |99878400     |995         |15              |
# |East  |50547700     |501         |15              |
# +------+-------------+------------+----------------+

# %%
monthly_revenue_trend = df_bronze \
    .withColumn('month', F.month('order_date')) \
    .groupBy('month') \
    .agg(\
        F.sum('revenue').alias('monthly_revenue'),\
        F.count('order_id').alias('monthly_orders')\
    ) \
    .orderBy('month') \
    .withColumnRenamed('month', 'order_month')

print('=== Monthly Revenue Trend ===')
monthly_revenue_trend.show(12)
# Out:
# === Monthly Revenue Trend ===
# +-----------+---------------+--------------+
# |order_month|monthly_revenue|monthly_orders|
# +-----------+---------------+--------------+
# |          1|       41068200|           423|
# |          2|       34485400|           375|
# |          3|       40031200|           451|
# |          4|       38857100|           390|
# |          5|       39984500|           423|
# |          6|       40707400|           390|
# |          7|       42640700|           405|
# |          8|       43718500|           418|
# |          9|       37640200|           398|
# |         10|       47839000|           479|
# |         11|       44577100|           419|
# |         12|       44298300|           429|
# +-----------+---------------+--------------+
